# %%
import robotdatapy as rdp

# %%
bag_path = "<DATA_DIR>/sando/visualization/single_agent_performance/big_forest_high_res/test8/bags/sando/num_0"
img_topic = "/NX01/d435/color/image_raw/compressed"
output_vid = "<DATA_DIR>/sando/visualization/single_agent_performance/big_forest_high_res/test8/bags/sando/output.mp4"


img_data = rdp.data.ImgData.from_bag(bag_path, img_topic, compressed=True)
img_data.show(img_data.t0)
img_data.to_mp4(output_vid)
