# %%
import robotdatapy as rdp

# %%
bag_path = "/media/kkondo/T7/sando/visualization/single_agent_performance/big_forest_high_res/test8/bags/sando/num_0"
img_topic = "/NX01/d435/color/image_raw/compressed"
output_vid = "/media/kkondo/T7/sando/visualization/single_agent_performance/big_forest_high_res/test8/bags/sando/output.mp4"


img_data = rdp.data.ImgData.from_bag(bag_path, img_topic, compressed=True)
img_data.show(img_data.t0)
img_data.to_mp4(output_vid)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 7
#       3 output_vid = "/media/kkondo/T7/sando/visualization/single_agent_performance/big_forest_high_res/test8/bags/sando/output.mp4"
#       6 img_data = rdp.data.ImgData.from_bag(bag_path, img_topic, compressed=False)
# ----> 7 img_data.show(img_data.t0)
#       8 img_data.to_mp4(output_vid)
#
# File ~/anaconda3/lib/python3.12/site-packages/robotdatapy/data/img_data.py:292, in ImgData.show(self, t, ax)
#     285 def show(self, t, ax=None):
#     286     """
#     287     Show image at time t.
#     288
#     289     Args:
#     290         t (float): time
#     291     """
# --> 292     img = self.img(t)
#     293     if ax is None:
#     294         _, ax = plt.subplots()
#
# File ~/anaconda3/lib/python3.12/site-packages/robotdatapy/data/img_data.py:283, in ImgData.img(self, t)
#     273 """
# ...
